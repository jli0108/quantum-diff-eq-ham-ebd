# %%
from advectionSolver import advectionSolver
from ionqStatePrepare import ionqSP
import numpy as np
from os import getenv
import utils
IONQ_API_KEY    = getenv("IONQ_API_KEY")

import matplotlib.pyplot as plt
dim = 2
size = 10
tList = np.linspace(0,0.2,3)
print(tList)
sp = ionqSP(size,dim)
sp.GaussDistribution2D()
# Out:
# [0.  0.1 0.2]

# %%
ad = advectionSolver(dim,[1,1])
idList = []
for t in tList:
    print("time: %f, trotter number: %d" % (t,min(t//0.05,1)))
    iq = ad.solve(size,t,"ionq",trotterNum=min(int(t//0.05),1),trotterOrder=2,circ=sp.circuit,onSimulator=True,noise=False)
    idList.append(iq.task['id'])
with open('simulation.txt','w') as f:
    for id in idList:
        f.write(f"{id}\n")
# Out:
# time: 0.000000, trotter number: 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 for t in tList:
#       4     print("time: %f, trotter number: %d" % (t,min(t//0.05,1)))
# ----> 5     iq = ad.solve(size,t,"ionq",trotterNum=min(int(t//0.05),1),trotterOrder=2,circ=sp.circuit,onSimulator=True,noise=False)
#       6     idList.append(iq.task['id'])
#       7 with open('simulation.txt','w') as f:
#
# File ~/Code/Qode/src/advectionSolver.py:50, in advectionSolver.solve(self, discretizeNum, timeLength, provider, trotterNum, trotterOrder, circ, onSimulator, noise)
#      48 if provider == "ionq":
#      49     if self.circ != None:
# ---> 50         self.iq.compile(self.qs, aais="2pauli",state_prep=self.circ, trotter_num=self.trotterNum,trotter_mode=self.trotterOrder,backend='aria-1')
#      51     else:
#      52         print("-----","Set initial state as 0","-----")
#
# File /opt/homebrew/anaconda3/envs/quantum/lib/python3.12/site-packages/simuq/ionq/ionq_provider.py:85, in IonQProvider.compile(self, qs, backend, aais, tol, trotter_num, trotter_mode, state_prep, meas_prep, verbose)
#      74 self.prog = comp(
#      75     qs.num_sites,
#      76     sol_gvars,
#    (...)
#      81     noise_model=backend,
#      82 )
#      84 if state_prep is not None:
# ---> 85     self.prog = state_prep.copy().add(self.prog, inherit_from_back=True)
#      87 if meas_prep is not None:
#      88     self.prog.add(meas_prep)
#
# File /opt/homebrew/anaconda3/envs/quantum/lib/python3.12/site-packages/simuq/ionq/ionq_api_circuit.py:105, in IonQAPICircuit.add(self, circ, inherit_from_back)
#     101 """
#     102 Append a circuit behind self
#     103 """
#     104 if len(circ._accum_phases) != len(self._accum_phases):
# --> 105     raise Exception("Circuit sizes are different.")
#     107 for gate in circ.job["input"]["circuit"]:
#     108     if gate["gate"] == "gpi":
#
# Exception: Circuit sizes are different.

# %%
idList = []
with open('simulation.txt','r') as f:
    for id in f:
        idList.append(id[:-1])
print(idList)
resList = [utils.resfromId(id,dim*size) for id in idList]
resDict = utils.resultGen(resList,size,dim)
mat = np.zeros((size,size,len(tList)))
keys = list(resDict.keys())
print(keys)
for tstep in range(len(tList)):
    for inx in range(len(resDict.keys())):
        row = inx // size
        col = inx % size
        mat[row][col][tstep] = resDict[keys[inx]][tstep]

for row in range(size):
    for col in range(size):
        print('%.5f' % mat[row][col][0],end=' ')
    print()

for i in range(len(tList)):
    fig = plt.figure()

    plt.imshow(mat[:,:,i])
    plt.title("Time = %.2f" % tList[i])
    plt.savefig('../Figs/simulation%d.png' % i)
    plt.show()
# Out:
# ['feb825b8-0504-4ef1-903a-4f17756fc10d', '6224df04-3b22-432a-99b4-3477fc3885cd', '07db4844-3b40-487f-93b5-e4c7106b7798']
# {'1q': 10, '2q': 35}
# {'1q': 88, '2q': 115}
# {'1q': 138, '2q': 115}
# ['00000000010000000001', '00000000010000000010', '00000000010000000100', '00000000010000001000', '00000000010000010000', '00000000010000100000', '00000000010001000000', '00000000010010000000', '00000000010100000000', '00000000011000000000', '00000000100000000001', '00000000100000000010', '00000000100000000100', '00000000100000001000', '00000000100000010000', '00000000100000100000', '00000000100001000000', '00000000100010000000', '00000000100100000000', '00000000101000000000', '00000001000000000001', '00000001000000000010', '00000001000000000100', '00000001000000001000', '00000001000000010000', '00000001000000100000', '00000001000001000000', '00000001000010000000', '00000001000100000000', '00000001001000000000', '00000010000000000001', '00000010000000000010', '00000010000000000100', '00000010000000001000', '00000010000000010000', '00000010000000100000', '00000010000001000000', '00000010000010000000', '00000010000100000000', '00000010001000000000', '00000100000000000001', '00000100000000000010', '00000100000000000100', '00000100000000001000', '00000100000000010000', '00000100000000100000', '00000100000001000000', '00000100000010000000', '00000100000100000000', '00000100001000000000', '00001000000000000001', '00001000000000000010', '00001000000000000100', '00001000000000001000', '00001000000000010000', '00001000000000100000', '00001000000001000000', '00001000000010000000', '00001000000100000000', '00001000001000000000', '00010000000000000001', '00010000000000000010', '00010000000000000100', '00010000000000001000', '00010000000000010000', '00010000000000100000', '00010000000001000000', '00010000000010000000', '00010000000100000000', '00010000001000000000', '00100000000000000001', '00100000000000000010', '00100000000000000100', '00100000000000001000', '00100000000000010000', '00100000000000100000', '00100000000001000000', '00100000000010000000', '00100000000100000000', '00100000001000000000', '01000000000000000001', '01000000000000000010', '01000000000000000100', '01000000000000001000', '01000000000000010000', '01000000000000100000', '01000000000001000000', '01000000000010000000', '01000000000100000000', '01000000001000000000', '10000000000000000001', '10000000000000000010', '10000000000000000100', '10000000000000001000', '10000000000000010000', '10000000000000100000', '10000000000001000000', '10000000000010000000', '10000000000100000000', '10000000001000000000']
# 0.00000 0.00000 0.00001 0.00001 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
# 0.00000 0.00022 0.00504 0.00504 0.00022 0.00000 0.00000 0.00000 0.00000 0.00000
# 0.00001 0.00504 0.11469 0.11469 0.00504 0.00000 0.00000 0.00000 0.00000 0.00000
# 0.00001 0.00504 0.11469 0.11469 0.00504 0.00000 0.00000 0.00000 0.00000 0.00000
# 0.00000 0.00022 0.00504 0.00504 0.00022 0.00000 0.00000 0.00000 0.00000 0.00000
# 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00001 0.00001 0.00000
# 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00022 0.00504 0.00504 0.00022
# 0.00000 0.00000 0.00000 0.00000 0.00000 0.00001 0.00504 0.11469 0.11469 0.00504
# 0.00000 0.00000 0.00000 0.00000 0.00000 0.00001 0.00504 0.11469 0.11469 0.00504
# 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00022 0.00504 0.00504 0.00022

# %%
adNoise = advectionSolver(dim,[1,1])
idNoiseList = []
for t in tList:
    print("time: %f, trotter number: %d" % (t,min(t//0.05,1)))
    iq = adNoise.solve(size,t,"ionq",trotterNum=min(int(t//0.05),1),trotterOrder=2,circ=sp.circuit,onSimulator=True,noise=True)
    idNoiseList.append(iq.task['id'])
with open('noise.txt','w') as f:
    for id in idNoiseList:
        f.write(f"{id}\n")

# %%
idList = []
with open('noise.txt','r') as f:
    for id in f:
        idList.append(id[:-1])
print(idList)
resList = [utils.resfromId(id,dim*size) for id in idList]
resDict = utils.resultGen(resList,size,dim)
mat = np.zeros((size,size,len(tList)))
keys = list(resDict.keys())
for tstep in range(len(tList)):
    for inx in range(len(resDict.keys())):
        row = inx // size
        col = inx % size
        mat[row][col][tstep] = resDict[keys[inx]][tstep]

for row in range(size):
    for col in range(size):
        print('%.5f' % mat[row][col][-1],end=' ')
    print()

for i in range(len(tList)):
    fig = plt.figure()

    plt.imshow(mat[:,:,i])
    plt.savefig('../Figs/noise%d.png' % i)
    plt.show()

# %%
adReal = advectionSolver(dim,[1,1])
idRealList = []
for t in tList:
    print("time: %f, trotter number: %d" % (t,min(t//0.05,1)))
    iq = adReal.solve(size,t,"ionq",trotterNum=min(int(t//0.05),1),trotterOrder=2,circ=sp.circuit,onSimulator=False)
    idRealList.append(iq.task['id'])
with open('real.txt','w') as f:
    for id in idRealList:
        f.write(f"{id}\n")

# %%
idList = []
with open('real.txt','r') as f:
    for id in f:
        idList.append(id[:-1])
print(idList)
resList = [utils.resfromId(id,dim*size) for id in idList]
resDict = utils.resultGen(resList,size,dim)
mat = np.zeros((size,size,len(tList)))
keys = list(resDict.keys())
for tstep in range(len(tList)):
    for inx in range(len(resDict.keys())):
        row = inx // size
        col = inx % size
        mat[row][col][tstep] = resDict[keys[inx]][tstep]

for row in range(size):
    for col in range(size):
        print('%.5f' % mat[row][col][-1],end=' ')
    print()

for i in range(len(tList)):
    fig = plt.figure()

    plt.imshow(mat[:,:,i])
    plt.savefig('../Figs/real%d.png' % i)
    plt.show()
